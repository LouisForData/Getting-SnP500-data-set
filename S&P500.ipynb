# %% [markdown]
# # Step One

# %%
import pandas as pd
import yfinance as yf

# %%
sp500url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
data_table = pd.read_html(sp500url)

# %%
data_table
# Out:
# [    Symbol              Security SEC filings             GICS Sector  \
#  0      MMM                    3M     reports             Industrials
#  1      AOS           A. O. Smith     reports             Industrials
#  2      ABT                Abbott     reports             Health Care
#  3     ABBV                AbbVie     reports             Health Care
#  4      ACN             Accenture     reports  Information Technology
#  ..     ...                   ...         ...                     ...
#  498    YUM           Yum! Brands     reports  Consumer Discretionary
#  499   ZBRA    Zebra Technologies     reports  Information Technology
#  500    ZBH         Zimmer Biomet     reports             Health Care
#  501   ZION  Zions Bancorporation     reports              Financials
#  502    ZTS                Zoetis     reports             Health Care
#
#                        GICS Sub-Industry    Headquarters Location  Date added  \
# ...

# %%
len(data_table)
# Out:
# 2

# %%
data_table[0]
# Out:
#     Symbol              Security SEC filings             GICS Sector  \
# 0      MMM                    3M     reports             Industrials
# 1      AOS           A. O. Smith     reports             Industrials
# 2      ABT                Abbott     reports             Health Care
# 3     ABBV                AbbVie     reports             Health Care
# 4     ABMD               Abiomed     reports             Health Care
# ..     ...                   ...         ...                     ...
# 498    YUM           Yum! Brands     reports  Consumer Discretionary
# 499   ZBRA    Zebra Technologies     reports  Information Technology
# 500    ZBH         Zimmer Biomet     reports             Health Care
# 501   ZION  Zions Bancorporation     reports              Financials
# 502    ZTS                Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# ...

# %%
data_table[0]['Symbol']
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4       ACN
#        ...
# 498     YUM
# 499    ZBRA
# 500     ZBH
# 501    ZION
# 502     ZTS
# Name: Symbol, Length: 503, dtype: object

# %%
ticker = data_table[0]['Symbol'].tolist()

# %%
ticker
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
# ...

# %%
len(ticker)
# Out:
# 503

# %%
yf.download('MMM', start='2001-01-01', end = '2022-11-29')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2001-01-02   59.062500   60.750000   58.750000   59.593750   33.493782
# 2001-01-03   59.000000   59.937500   58.187500   58.906250   33.107357
# 2001-01-04   58.937500   59.750000   57.781250   59.500000   33.441074
# 2001-01-05   58.500000   58.500000   55.281250   57.281250   32.194057
# 2001-01-08   56.500000   57.687500   54.781250   57.625000   32.387257
# ...                ...         ...         ...         ...         ...
# 2022-11-21  126.639999  127.879997  126.230003  127.629997  127.629997
# 2022-11-22  128.149994  128.669998  127.320000  128.600006  128.600006
# 2022-11-23  128.589996  129.119995  127.239998  128.000000  128.000000
# 2022-11-25  128.880005  129.820007  128.520004  129.039993  129.039993
# 2022-11-28  128.110001  128.580002  124.120003  124.639999  124.639999
#
#              Volume
# Date
# ...

# %% [markdown]
# # Step Two

# %%
snp_prices = yf.download(ticker, start='2001-01-01', end = '2022-11-29')
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 3 Failed downloads:
# - BRK.B: No data found for this date range, symbol may be delisted
# - GEHC: Data doesn't exist for startDate = 978325200, endDate = 1669698000
# - BF.B: No data found for this date range, symbol may be delisted

# %%
snp_prices
# Out:
#              Adj Close                                                         \
#                      A    AAL         AAP        AAPL        ABBV         ABC
# Date
# 2001-01-02   31.091185    NaN         NaN    0.226423         NaN    9.620434
# 2001-01-03   34.299583    NaN         NaN    0.249256         NaN    9.813094
# 2001-01-04   35.598248    NaN         NaN    0.259722         NaN    9.006370
# 2001-01-05   33.650265    NaN         NaN    0.249256         NaN    8.693316
# 2001-01-08   32.542595    NaN         NaN    0.252110         NaN    9.223099
# ...                ...    ...         ...         ...         ...         ...
# 2022-11-21  144.923859  13.85  146.690033  148.009995  155.630554  160.300003
# 2022-11-22  156.626404  13.98  147.986328  150.179993  158.285324  164.710007
# 2022-11-23  155.118668  14.42  148.975876  151.070007  157.889084  165.529999
# 2022-11-25  156.726273  14.50  148.431625  148.110001  158.116928  167.699997
# ...

# %%
snp_prices = yf.download(ticker, start='2001-01-01', end = '2022-11-29')['Adj Close']
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 3 Failed downloads:
# - BRK.B: No data found for this date range, symbol may be delisted
# - GEHC: Data doesn't exist for startDate = 978325200, endDate = 1669698000
# - BF.B: No data found for this date range, symbol may be delisted

# %%
snp_prices.isna().any()
# Out:
# A       False
# AAL      True
# AAP      True
# AAPL    False
# ABBV     True
#         ...
# YUM     False
# ZBH      True
# ZBRA    False
# ZION    False
# ZTS      True
# Length: 503, dtype: bool

# %%
snp_prices.loc[:, snp_prices.isna().any()]
# Out:
#               AAL         AAP        ABBV         ACN         AIZ        ALGN  \
# Date
# 2001-01-02    NaN         NaN         NaN         NaN         NaN         NaN
# 2001-01-03    NaN         NaN         NaN         NaN         NaN         NaN
# 2001-01-04    NaN         NaN         NaN         NaN         NaN         NaN
# 2001-01-05    NaN         NaN         NaN         NaN         NaN         NaN
# 2001-01-08    NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 2022-11-21  13.85  148.240005  157.110001  287.019989  125.802971  191.630005
# 2022-11-22  13.98  149.550003  159.789993  292.890015  126.479225  191.389999
# 2022-11-23  14.42  150.550003  159.389999  294.529999  126.339996  196.279999
# 2022-11-25  14.50  150.000000  159.619995  296.399994  128.490005  194.669998
# 2022-11-28  13.83  150.619995  158.429993  290.600006  125.220001  189.779999
#
# ...

# %%
yf.download('BRK-B')['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 1996-05-09     23.200001
# 1996-05-10     24.000000
# 1996-05-13     23.900000
# 1996-05-14     23.600000
# 1996-05-15     23.200001
#                  ...
# 2023-01-10    316.350006
# 2023-01-11    320.369995
# 2023-01-12    318.929993
# 2023-01-13    317.640015
# 2023-01-17    314.859985
# Name: Adj Close, Length: 6718, dtype: float64

# %%
yf.download('BF-B')['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 1980-03-17     0.198797
# 1980-03-18     0.198797
# 1980-03-19     0.201457
# 1980-03-20     0.202121
# 1980-03-21     0.199462
#                 ...
# 2023-01-10    65.260002
# 2023-01-11    66.129997
# 2023-01-12    65.669998
# 2023-01-13    67.070000
# 2023-01-17    68.000000
# Name: Adj Close, Length: 10801, dtype: float64

# %%
'BF-B' in ticker
# Out:
# False

# %%
'BRK-B' in ticker
# Out:
# False

# %%
for i in range(len(ticker)):
    if ticker[i] == 'BRK.B':
        ticker[i] = 'BRK-B'
    elif ticker[i] == 'BF.B':
        ticker[i] = 'BF-B'

# %%
'BF-B' in ticker
# Out:
# True

# %%
'BRK-B' in ticker
# Out:
# True

# %%
len(ticker)
# Out:
# 503

# %%
snp_prices = yf.download(ticker, start='2001-01-01', end = '2022-11-29')
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 3 Failed downloads:
# - ETN: No data found for this date range, symbol may be delisted
# - GEHC: Data doesn't exist for startDate = 978325200, endDate = 1669698000
# - ENPH: No data found for this date range, symbol may be delisted

# %%
snp_prices
# Out:
#              Adj Close                                                         \
#                      A    AAL         AAP        AAPL        ABBV         ABC
# Date
# 2001-01-02   31.091166    NaN         NaN    0.226424         NaN    9.620441
# 2001-01-03   34.299606    NaN         NaN    0.249256         NaN    9.813087
# 2001-01-04   35.598248    NaN         NaN    0.259721         NaN    9.006368
# 2001-01-05   33.650276    NaN         NaN    0.249256         NaN    8.693312
# 2001-01-08   32.542606    NaN         NaN    0.252110         NaN    9.223098
# ...                ...    ...         ...         ...         ...         ...
# 2022-11-21  144.923859  13.85  146.690033  148.009995  155.630554  160.300003
# 2022-11-22  156.626404  13.98  147.986328  150.179993  158.285324  164.710007
# 2022-11-23  155.118668  14.42  148.975876  151.070007  157.889084  165.529999
# 2022-11-25  156.726273  14.50  148.431625  148.110001  158.116928  167.699997
# ...

# %%
snp_prices[['BRK-B', 'BF-B']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 snp_prices[['BRK-B', 'BF-B']]
#
# File c:\Users\louis\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\louis\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:2623, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2620 if len(keyarr) and not isinstance(keyarr[0], tuple):
#    2621     indexer = self._get_indexer_level_0(keyarr)
# -> 2623     self._raise_if_missing(key, indexer, axis_name)
# ...

# %%
snp_prices.shape
# Out:
# (5512, 3018)

# %%
snp_prices = yf.download(ticker, start='2001-01-01', end = '2022-12-13')['Adj Close']
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 1 Failed download:
# - GEHC: Data doesn't exist for startDate = 978325200, endDate = 1670907600

# %% [markdown]
# Step Three

# %%
snp_prices
# Out:
#                      A    AAL         AAP        AAPL        ABBV         ABC  \
# Date
# 2001-01-02   31.091171    NaN         NaN    0.226423         NaN    9.620437
# 2001-01-03   34.299606    NaN         NaN    0.249256         NaN    9.813091
# 2001-01-04   35.598240    NaN         NaN    0.259721         NaN    9.006367
# 2001-01-05   33.650272    NaN         NaN    0.249256         NaN    8.693313
# 2001-01-08   32.542599    NaN         NaN    0.252110         NaN    9.223099
# ...                ...    ...         ...         ...         ...         ...
# 2022-12-06  151.124619  14.33  144.008362  142.910004  162.178314  169.320007
# 2022-12-07  153.501068  13.55  145.116638  140.940002  163.842499  170.289993
# 2022-12-08  156.047272  13.60  145.057266  142.649994  164.426941  170.460007
# 2022-12-09  152.722229  13.53  144.374481  142.160004  161.524536  165.330002
# 2022-12-12  155.098694  14.20  144.404175  144.490005  163.763260  167.199997
#
# ...

# %%
snp_prices
# Out:
#                      A    AAL         AAP        AAPL        ABBV         ABC  \
# Date
# 2001-01-02   31.091171    NaN         NaN    0.226423         NaN    9.620437
# 2001-01-03   34.299606    NaN         NaN    0.249256         NaN    9.813091
# 2001-01-04   35.598240    NaN         NaN    0.259721         NaN    9.006367
# 2001-01-05   33.650272    NaN         NaN    0.249256         NaN    8.693313
# 2001-01-08   32.542599    NaN         NaN    0.252110         NaN    9.223099
# ...                ...    ...         ...         ...         ...         ...
# 2022-12-06  151.124619  14.33  144.008362  142.910004  162.178314  169.320007
# 2022-12-07  153.501068  13.55  145.116638  140.940002  163.842499  170.289993
# 2022-12-08  156.047272  13.60  145.057266  142.649994  164.426941  170.460007
# 2022-12-09  152.722229  13.53  144.374481  142.160004  161.524536  165.330002
# 2022-12-12  155.098694  14.20  144.404175  144.490005  163.763260  167.199997
#
# ...

# %%
 snp_prices.head()
# Out:
# Date
# 2001-01-02    4.550942
# 2001-01-03    4.481195
# 2001-01-04    4.219647
# 2001-01-05    4.219647
# 2001-01-08    4.224007
# Name: Adj Close, dtype: float64

# %%
snpdatafinal = pd.DataFrame(snp_prices)

# %%
snpdatafinal
# Out:
#             Adj Close
# Date
# 2001-01-02   4.550943
# 2001-01-03   4.481195
# 2001-01-04   4.219644
# 2001-01-05   4.219644
# 2001-01-08   4.224004
# ...               ...
# 2022-11-21  70.470001
# 2022-11-22  72.239998
# 2022-11-23  72.570000
# 2022-11-25  72.730003
# 2022-11-28  71.930000
#
# [5512 rows x 1 columns]

# %%
snp_data_to_csv4 = snpdatafinal.to_csv('C:/Users/louis/Downloads/snp_500_data9.csv')
